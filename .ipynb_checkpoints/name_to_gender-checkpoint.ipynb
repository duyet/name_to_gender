# %%
import pandas as pd

# %%
with open('./girl.name.dict.txt') as f:
    name_dict = f.read().splitlines()

# %%
data = pd.read_csv('./data/user_ids.with_name.txt', sep=',', names=('uid', 'name', 'gender'))
data.head()
# Out:
#                uid                name  gender
# 0  100000039738608         Nguyễn Trâm  female
# 1  100000030623921  Quần Đùi Thủng Đít    male
# 2  100000118849954           Jack Lion    male
# 3  100000030552273         Nguyễn Linh    male
# 4  100000204131248           Mạnh Long    male

# %%
data['gender_pred'] = data.name.apply(lambda name: 'female' if any(s in name for s in name_dict) else 'male')
data['correct'] = data.apply(lambda row: True if row['gender'] == row['gender_pred'] else False, axis=1)

# %%
n_correct = len(data[data.correct == True])
n = len(data)

print 'Correct %s / %s (%s%%)' % (n_success, n, n_correct * 100.0 / n)
# Out:
# Correct 2494 / 4108 (60.7108081792%)

# %%
test = data[data.correct == False]
test[test.gender == 'female']
# Out:
#                   uid                 name gender gender_pred correct
# 3     100000030552273          Nguyễn Linh   male      female   False
# 6     100000109767174        Nguyen Ba Tho   male      female   False
# 9     100000282974698    Trần Đức Mùa Xuân   male      female   False
# 13    100000249593975             Dương KT   male      female   False
# 14    100000075838412            Pham Tung   male      female   False
# 17    100000253440179        Thao Le Quang   male      female   False
# 18    100000272722918      Trinh Ngoc Diep   male      female   False
# 19    100000135119392           Yester Day   male      female   False
# 21    100000187704911           Hieu Hoang   male      female   False
# 40    100000265401718         Quang Nguyễn   male      female   False
# 45    100000283052782             Độc Hành   male      female   False
# 50    100000194131619       Thành Công Lưu   male      female   False
# 52    100000292819005          Đỗ Chí Miền   male      female   False
# 54    100000038036402           Khang Phan   male      female   False
# 55    100000174973699      Nguyễn Việt Anh   male      female   False
# 58    100000216637677             Khang VD   male      female   False
# 59    100000227697405           Hoàng Vĩnh   male      female   False
# 61    100000029957716           Tuấn Dương   male      female   False
# 62    100000271476535       Phạm Cường Anh   male      female   False
# 64    100000271272273        Trần Đức Viễn   male      female   False
# 65    100000222465492        Vu Nhat Quang   male      female   False
# 66    100000061801739     Dung Nguyen Dinh   male      female   False
# 67    100000224365353  Phạm Ngọc Đức Quang   male      female   False
# 76    100000272244301        Giang Takidon   male      female   False
# 78    100000244178247          Trần Tú Văn   male      female   False
# 79    100000044177159           Phan Giang   male      female   False
# 81    100000249577142             Linh Huê   male      female   False
# 84    100000258376219             Anh Dũng   male      female   False
# 88    100000021054983    Hieu Nguyen Thanh   male      female   False
# 90    100000219251610     Nguyễn Chí Thiện   male      female   False
# ...               ...                  ...    ...         ...     ...
# 3977  100000758766503         Võ Trọng Lâm   male      female   False
# 3979  100000757381526              Hùng Lê   male      female   False
# 3983  100000760150684              Vu Hiep   male      female   False
# 3993  100000770841617     Nguyen Anh Quynh   male      female   False
# 3998  100000775796886               Nam Vu   male      female   False
# 3999  100000762108731           Hải Nguyễn   male      female   False
# 4002  100000771215726  Nguyễn Trương Kỳ Vỹ   male      female   False
# 4006  100000769778648       Mai Tien Thanh   male      female   False
# 4007  100000768880800           Phuong Cnc   male      female   False
# 4011  100000778870474        Tuấn Mạnh Lại   male      female   False
# 4026  100000789125376         Khánh Nguyễn   male      female   False
# 4028  100000795207424           Hoàng Trần   male      female   False
# 4029  100000794369689         Đỗ Mạnh Hiếu   male      female   False
# 4030  100000780927350             Trần Anh   male      female   False
# 4031  100000789791291          Thanh Quang   male      female   False
# 4032  100000798915897              Bảo Duy   male      female   False
# 4033  100000798822091              Đức Lộc   male      female   False
# 4045  100000797847589           Phúc Hoàng   male      female   False
# 4046  100000797030132          Tung Nguyen   male      female   False
# 4048  100000797494682           Nghia Tran   male      female   False
# 4050  100000797024530      Hoàng Xuân Quân   male      female   False
# 4073  100000809330890       Đoàn Xuân Bách   male      female   False
# 4077  100000804185879    Phong Ngọc Nguyễn   male      female   False
# 4078  100000806387525               Van Le   male      female   False
# 4079  100000803990280      Nguyễn Gia Tuấn   male      female   False
# 4082  100000807340047            Minh Trần   male      female   False
# 4090  100000816690040              Lee Sin   male      female   False
# 4092  100000816461929        Đinh Văn Minh   male      female   False
# 4095  100000819424619             Tuan Anh   male      female   False
# 4098  100000823430504            Lê Mỹ Huy   male      female   False
#
# [1129 rows x 5 columns]
