# %%
import pandas as pd

# %%
with open('./girl.name.dict.txt') as f:
    name_dict = f.read().splitlines()

# %%
data = pd.read_csv('./data/user_ids.with_name.txt', sep=',', names=('uid', 'name', 'gender'))
data.head()
# Out:
#                uid                name  gender
# 0  100000039738608         Nguyễn Trâm  female
# 1  100000030623921  Quần Đùi Thủng Đít    male
# 2  100000118849954           Jack Lion    male
# 3  100000030552273         Nguyễn Linh    male
# 4  100000204131248           Mạnh Long    male

# %%
data['gender_pred'] = data.name.apply(lambda name: 'female' if any(s in name for s in name_dict) else 'male')
data['correct'] = data.apply(lambda row: True if row['gender'] == row['gender_pred'] else False, axis=1)

# %%
n_correct = len(data[data.correct == True])
n = len(data)

print 'Correct %s / %s (%s%%)' % (n_success, n, n_correct * 100.0 / n)
# Out:
# Correct 2494 / 4108 (60.7108081792%)

# %%
test = data[data.correct == False]
test[test.gender == 'female']
# Out:
#                   uid                 name  gender gender_pred correct
# 10    100000184926990              Khoa Đỗ  female        male   False
# 20    100000024467596   nguyễn phương thảo  female        male   False
# 26    100000244764070  Võ Trịnh Đình Nghĩa  female        male   False
# 32    100000073370880      Phạm Hùng Cường  female        male   False
# 39    100000270894265            Thành Huy  female        male   False
# 43    100000031023535             Tân Phạm  female        male   False
# 47    100000120118842              Đỗ Tiến  female        male   False
# 63    100000215815299            Mạnh Hùng  female        male   False
# 77    100000258442577           Trần Trịnh  female        male   False
# 80    100000194750396               Mèo Mở  female        male   False
# 85    100000184398404              Aron HP  female        male   False
# 89    100000149782466          Cùi Mía Lùi  female        male   False
# 100   100000240157456            Pham Hung  female        male   False
# 114   100000121567927          Tânn Nguyễn  female        male   False
# 116   100000180848309                AN CO  female        male   False
# 119   100000238157624        Luxuryy Cường  female        male   False
# 141   100000254565777          Iliked Buoi  female        male   False
# 148   100000128964607          Melodic Sen  female        male   False
# 150   100000215533156           Huy Nguyễn  female        male   False
# 156   100000077463662            Quốc Vĩnh  female        male   False
# 174   100000239191899            Tejpi Huy  female        male   False
# 191   100000228605282             Tiến Bùi  female        male   False
# 202   100000296169724             Trần Tấn  female        male   False
# 207   100000269675266          Nguyễn Long  female        male   False
# 209   100000226134626      Đình Thắng Trần  female        male   False
# 226   100000206231013         Cháo Gỏi Vịt  female        male   False
# 228   100000258140894      Stephanie Black  female        male   False
# 232   100000020115740            Ớt Nguyễn  female        male   False
# 238   100000182690851           Marl Trắng  female        male   False
# 242   100000145767670              Heo Con  female        male   False
# ...               ...                  ...     ...         ...     ...
# 3901  100000713218988    Nguyễn Thành Nhâm  female        male   False
# 3909  100000726890458        Mùa Chai Cẳng  female        male   False
# 3953  100000752785821            Tiệp Phạm  female        male   False
# 3965  100000752438286             Văn Khoa  female        male   False
# 3970  100000759688016               Bi Boo  female        male   False
# 3975  100000760398736             Bầu Trời  female        male   False
# 3988  100000765288592         Thành Tài Tạ  female        male   False
# 3990  100000763928615             Tân Trần  female        male   False
# 3997  100000775679206         Bắc Khói Lửa  female        male   False
# 4001  100000770798824           Xiu Xau Xi  female        male   False
# 4009  100000772666144           Thành Phát  female        male   False
# 4013  100000773132162           Thành Long  female        male   False
# 4025  100000789152845      Đặng Hưng Thịnh  female        male   False
# 4035  100000786234234            Mạnh Hưng  female        male   False
# 4039  100000790255004                Hu Lu  female        male   False
# 4042  100000795639226              Nam Shu  female        male   False
# 4043  100000787132731          Tiến Nguyễn  female        male   False
# 4047  100000798519530          Tên Là Long  female        male   False
# 4049  100000796976145       Chue Dzan Wiee  female        male   False
# 4052  100000796549274             Nhạt Dần  female        male   False
# 4057  100000796277892            Cong Than  female        male   False
# 4060  100000801252301        Thế Hiển Trần  female        male   False
# 4065  100000817061821         Trần Timothy  female        male   False
# 4075  100000811695955        Đạt Đương Đại  female        male   False
# 4080  100000806489232             Người Lạ  female        male   False
# 4083  100000806692233       Nguyễn Huy Đôn  female        male   False
# 4087  100000818062663               Cậu Út  female        male   False
# 4091  100000817873116             Thịnh Tạ  female        male   False
# 4097  100000823298634          Nguyễn Dũng  female        male   False
# 4100  100000824921651            Alex Quốc  female        male   False
#
# [485 rows x 5 columns]
